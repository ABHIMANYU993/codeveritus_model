# %%
import torch
from torch import nn
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
from datasets import load_dataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from torch.cuda.amp import autocast, GradScaler


import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# Step 1: Load the datasets
human_dataset = load_dataset("bigcode/humanevalpack", split="test")
ai_dataset = load_dataset("Rabinovich/Code-Generation-LLM-LoRA", split="train")
# Print dataset sizes
print(f"Size of human dataset: {len(human_dataset)}")
print(f"Size of AI dataset: {len(ai_dataset)}")

# Sample sizes
human_sample_size = min(164, len(human_dataset))
ai_sample_size = min(10000, len(ai_dataset))

# Select subsets
human_dataset = human_dataset.select(range(human_sample_size))
ai_dataset = ai_dataset.select(range(ai_sample_size))

# Step 2: Preprocess datasets
tokenizer = RobertaTokenizer.from_pretrained("microsoft/codebert-base")

def preprocess_dataset(dataset, label, column_name, bug_type_column=None):
    tokenized_samples = []
    labels = []
    attention_masks = []
    bug_types = []

    for idx, code_sample in enumerate(dataset[column_name]):
        tokenized_input = tokenizer(
            code_sample,
            padding='max_length',
            truncation=True,
            max_length=512,
            return_tensors='pt'
        )
        tokenized_samples.append(tokenized_input['input_ids'].squeeze(0))
        labels.append(label)
        attention_masks.append(tokenized_input['attention_mask'].squeeze(0))

        # If human-written code, add bug type if specified
        if bug_type_column and label == 0:
            bug_types.append(dataset[bug_type_column][idx])
        else:
            bug_types.append('ai_generated' if label == 1 else None)

    return tokenized_samples, labels, attention_masks, bug_types

# Preprocess human-written code dataset (using buggy_solution) and include bug_type
human_tokens, human_labels, human_attention_masks, human_bug_types = preprocess_dataset(
    human_dataset,
    0,
    'canonical_solution',
    bug_type_column='bug_type'
)

# Preprocess AI-generated code dataset (using content)
ai_tokens, ai_labels, ai_attention_masks, _ = preprocess_dataset(
    ai_dataset,
    1,
    'answer'
)

# Combine datasets
tokens = human_tokens + ai_tokens
labels = human_labels + ai_labels
attention_masks = human_attention_masks + ai_attention_masks

# Convert to PyTorch tensors
tokens = torch.stack(tokens)
labels = torch.tensor(labels)
attention_masks = torch.stack(attention_masks)

# Step 3: Define the CodeBERT model with Dropout
class CodeBERTClassifier(nn.Module):
    def __init__(self):
        super(CodeBERTClassifier, self).__init__()
        self.model = RobertaForSequenceClassification.from_pretrained("microsoft/codebert-base", num_labels=2)
        self.dropout = nn.Dropout(p=0.35)  # Add a dropout layer

    def forward(self, input_ids, attention_mask=None):
        outputs = self.model(input_ids, attention_mask=attention_mask)
        logits = self.dropout(outputs.logits)  # Apply dropout
        return logits

# Step 4: Split the data into training and validation sets
train_indices, val_indices = train_test_split(list(range(len(tokens))), test_size=0.2, random_state=42)

# Split the dataset
X_train, X_val = tokens[train_indices], tokens[val_indices]
y_train, y_val = labels[train_indices], labels[val_indices]
masks_train, masks_val = attention_masks[train_indices], attention_masks[val_indices]

# Create PyTorch Dataset and DataLoader
train_dataset = torch.utils.data.TensorDataset(X_train, y_train, masks_train)
val_dataset = torch.utils.data.TensorDataset(X_val, y_val, masks_val)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=16)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=16)

# Step 5: Define training function with FP16
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CodeBERTClassifier().to(device)
optimizer = AdamW(model.parameters(), lr=2.5e-5, weight_decay=1e-5)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)
scaler = GradScaler()

# Compute class weights to handle class imbalance
class_weights = torch.tensor([len(ai_labels) / len(human_labels), 1.0], device='cpu').to('cuda')  # Modify to your dataset
loss_fn = nn.CrossEntropyLoss(weight=class_weights)

def train_model(model, train_loader, val_loader, optimizer, scheduler, loss_fn, num_epochs=6, patience=2):
    torch.cuda.empty_cache()
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    best_val_loss = float('inf')
    epochs_without_improvement = 0

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        correct_predictions = 0
        total_predictions = 0

        for batch_idx, batch in enumerate(train_loader):
            input_ids, labels, attention_mask = batch[0].to(device), batch[1].to(device), batch[2].to(device)
            optimizer.zero_grad()

            with autocast():  # Mixed precision training
                outputs = model(input_ids, attention_mask=attention_mask)
                loss = loss_fn(outputs, labels)

            # Scale loss and perform backward pass
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()
            _, preds = torch.max(outputs, dim=1)
            correct_predictions += torch.sum(preds == labels).item()
            total_predictions += labels.size(0)

            if batch_idx % 10 == 0:  # Print every 10 batches
                print(f"Epoch [{epoch + 1}/{num_epochs}], Batch [{batch_idx}], Loss: {loss.item():.4f}")

        avg_loss = total_loss / len(train_loader)
        accuracy = correct_predictions / total_predictions
        print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for batch in val_loader:
                input_ids, labels, attention_mask = batch[0].to(device), batch[1].to(device), batch[2].to(device)

                with autocast():
                    outputs = model(input_ids, attention_mask=attention_mask)
                    loss = loss_fn(outputs, labels)

                val_loss += loss.item()
                _, preds = torch.max(outputs, dim=1)
                val_correct += torch.sum(preds == labels).item()
                val_total += labels.size(0)

        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = val_correct / val_total
        print(f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")

        # Step the scheduler
        scheduler.step()

        # Early stopping logic
        train_losses.append(avg_loss)
        val_losses.append(avg_val_loss)
        train_accuracies.append(accuracy)
        val_accuracies.append(val_accuracy)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1
            if epochs_without_improvement >= patience:
                print(f"Early stopping triggered after {epoch + 1} epochs.")
                break

    return train_losses, val_losses, train_accuracies, val_accuracies

# Train the model
train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, optimizer, scheduler, loss_fn, num_epochs=6, patience=2
)

# Save the trained model
save_path = f"E:/python-projects/llm/Trained_models/codebert_classifier{max(train_accuracies)}.pth"
torch.save(model.state_dict(), save_path)
print(f"Model saved to {save_path}")

# Step 7: Plot training and validation loss/accuracy
epochs_range = range(1, len(train_losses) + 1)
plt.figure(figsize=(12, 5))

# Plotting Loss
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_losses, label='Training Loss')
plt.plot(epochs_range, val_losses, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plotting Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_accuracies, label='Training Accuracy')
plt.plot(epochs_range, val_accuracies, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Size of human dataset: 164
# Size of AI dataset: 34727
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at microsoft/codebert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# E:\python-projects\llm\cuda\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:370: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# Epoch [1/6], Batch [0], Loss: 0.7194
# Epoch [1/6], Batch [10], Loss: 0.1305
# Epoch [1/6], Batch [20], Loss: 0.1317
# Epoch [1/6], Batch [30], Loss: 0.2044
# Epoch [1/6], Batch [40], Loss: 0.9595
# Epoch [1/6], Batch [50], Loss: 0.0692
# Epoch [1/6], Batch [60], Loss: 0.0760
# Epoch [1/6], Batch [70], Loss: 0.1264
# Epoch [1/6], Batch [80], Loss: 0.2391
# Epoch [1/6], Batch [90], Loss: 0.8150
# Epoch [1/6], Batch [100], Loss: 0.1723
# Epoch [1/6], Batch [110], Loss: 0.0262
# Epoch [1/6], Batch [120], Loss: 0.1074
# Epoch [1/6], Batch [130], Loss: 0.3828
# Epoch [1/6], Batch [140], Loss: 0.2850
# Epoch [1/6], Batch [150], Loss: 0.0137
# Epoch [1/6], Batch [160], Loss: 0.0175
# Epoch [1/6], Batch [170], Loss: 0.5943
# Epoch [1/6], Batch [180], Loss: 0.1360
# Epoch [1/6], Batch [190], Loss: 0.0954
# Epoch [1/6], Batch [200], Loss: 0.0080
# Epoch [1/6], Batch [210], Loss: 0.0501
# Epoch [1/6], Batch [220], Loss: 0.0894
# Epoch [1/6], Batch [230], Loss: 0.1361
# Epoch [1/6], Batch [240], Loss: 0.9642
# Epoch [1/6], Batch [250], Loss: 0.1177
# Epoch [1/6], Batch [260], Loss: 0.0068
# Epoch [1/6], Batch [270], Loss: 0.0467
# Epoch [1/6], Batch [280], Loss: 0.0482
# Epoch [1/6], Batch [290], Loss: 0.0472
# Epoch [1/6], Batch [300], Loss: 0.0461
# Epoch [1/6], Batch [310], Loss: 0.0902
# Epoch [1/6], Batch [320], Loss: 0.0479
# Epoch [1/6], Batch [330], Loss: 0.0457
# Epoch [1/6], Batch [340], Loss: 0.0466
# Epoch [1/6], Batch [350], Loss: 0.0879
# Epoch [1/6], Batch [360], Loss: 0.0877
# Epoch [1/6], Batch [370], Loss: 0.0448
# Epoch [1/6], Batch [380], Loss: 0.0170
# Epoch [1/6], Batch [390], Loss: 0.1760
# Epoch [1/6], Batch [400], Loss: 0.1750
# Epoch [1/6], Batch [410], Loss: 0.0120
# Epoch [1/6], Batch [420], Loss: 0.1749
# Epoch [1/6], Batch [430], Loss: 0.1749
# Epoch [1/6], Batch [440], Loss: 1.6325
# Epoch [1/6], Batch [450], Loss: 0.0527
# Epoch [1/6], Batch [460], Loss: 0.2004
# Epoch [1/6], Batch [470], Loss: 0.0027
# Epoch [1/6], Batch [480], Loss: 0.1758
# Epoch [1/6], Batch [490], Loss: 0.0494
# Epoch [1/6], Batch [500], Loss: 0.0889
# Epoch 1/6, Loss: 0.1889, Accuracy: 0.8723
# Validation Loss: 0.0131, Validation Accuracy: 0.9956
# Epoch [2/6], Batch [0], Loss: 0.1313
# Epoch [2/6], Batch [10], Loss: 0.0447
# Epoch [2/6], Batch [20], Loss: 0.0456
# Epoch [2/6], Batch [30], Loss: 0.0886
# Epoch [2/6], Batch [40], Loss: 0.0882
# Epoch [2/6], Batch [50], Loss: 0.0558
# Epoch [2/6], Batch [60], Loss: 0.1320
# Epoch [2/6], Batch [70], Loss: 0.0459
# Epoch [2/6], Batch [80], Loss: 0.0282
# Epoch [2/6], Batch [90], Loss: 0.5661
# Epoch [2/6], Batch [100], Loss: 0.0462
# Epoch [2/6], Batch [110], Loss: 0.0027
# Epoch [2/6], Batch [120], Loss: 0.0892
# Epoch [2/6], Batch [130], Loss: 0.1755
# Epoch [2/6], Batch [140], Loss: 0.5570
# Epoch [2/6], Batch [150], Loss: 0.0884
# Epoch [2/6], Batch [160], Loss: 0.0451
# Epoch [2/6], Batch [170], Loss: 0.0457
# Epoch [2/6], Batch [180], Loss: 0.0366
# Epoch [2/6], Batch [190], Loss: 0.1316
# Epoch [2/6], Batch [200], Loss: 0.0488
# Epoch [2/6], Batch [210], Loss: 0.0523
# Epoch [2/6], Batch [220], Loss: 0.0446
# Epoch [2/6], Batch [230], Loss: 0.1315
# Epoch [2/6], Batch [240], Loss: 0.0888
# Epoch [2/6], Batch [250], Loss: 0.0447
# Epoch [2/6], Batch [260], Loss: 0.1032
# Epoch [2/6], Batch [270], Loss: 0.0345
# Epoch [2/6], Batch [280], Loss: 0.0268
# Epoch [2/6], Batch [290], Loss: 0.1747
# Epoch [2/6], Batch [300], Loss: 0.1324
# Epoch [2/6], Batch [310], Loss: 0.0451
# Epoch [2/6], Batch [320], Loss: 0.0459
# Epoch [2/6], Batch [330], Loss: 0.0016
# Epoch [2/6], Batch [340], Loss: 0.0660
# Epoch [2/6], Batch [350], Loss: 0.0188
# Epoch [2/6], Batch [360], Loss: 0.1320
# Epoch [2/6], Batch [370], Loss: 0.0879
# Epoch [2/6], Batch [380], Loss: 0.1893
# Epoch [2/6], Batch [390], Loss: 0.1318
# Epoch [2/6], Batch [400], Loss: 0.0547
# Epoch [2/6], Batch [410], Loss: 0.0454
# Epoch [2/6], Batch [420], Loss: 0.0453
# Epoch [2/6], Batch [430], Loss: 0.5842
# Epoch [2/6], Batch [440], Loss: 0.0012
# Epoch [2/6], Batch [450], Loss: 0.0893
# Epoch [2/6], Batch [460], Loss: 0.0279
# Epoch [2/6], Batch [470], Loss: 0.0383
# Epoch [2/6], Batch [480], Loss: 0.0449
# Epoch [2/6], Batch [490], Loss: 0.0019
# Epoch [2/6], Batch [500], Loss: 0.0026
# Epoch 2/6, Loss: 0.0964, Accuracy: 0.8786
# Validation Loss: 0.0275, Validation Accuracy: 0.9951
# Epoch [3/6], Batch [0], Loss: 0.0098
# Epoch [3/6], Batch [10], Loss: 0.0448
# Epoch [3/6], Batch [20], Loss: 0.1306
# Epoch [3/6], Batch [30], Loss: 0.0462
# Epoch [3/6], Batch [40], Loss: 0.0442
# Epoch [3/6], Batch [50], Loss: 0.9086
# Epoch [3/6], Batch [60], Loss: 0.2177
# Epoch [3/6], Batch [70], Loss: 0.1311
# Epoch [3/6], Batch [80], Loss: 0.1744
# Epoch [3/6], Batch [90], Loss: 0.0106
# Epoch [3/6], Batch [100], Loss: 0.1320
# Epoch [3/6], Batch [110], Loss: 0.0449
# Epoch [3/6], Batch [120], Loss: 0.1339
# Epoch [3/6], Batch [130], Loss: 0.0453
# Epoch [3/6], Batch [140], Loss: 0.0311
# Epoch [3/6], Batch [150], Loss: 0.0450
# Epoch [3/6], Batch [160], Loss: 0.0108
# Epoch [3/6], Batch [170], Loss: 0.0373
# Epoch [3/6], Batch [180], Loss: 0.0447
# Epoch [3/6], Batch [190], Loss: 0.0100
# Epoch [3/6], Batch [200], Loss: 0.0372
# Epoch [3/6], Batch [210], Loss: 0.0453
# Epoch [3/6], Batch [220], Loss: 0.0284
# Epoch [3/6], Batch [230], Loss: 0.2186
# Epoch [3/6], Batch [240], Loss: 0.0628
# Epoch [3/6], Batch [250], Loss: 0.0017
# Epoch [3/6], Batch [260], Loss: 0.0662
# Epoch [3/6], Batch [270], Loss: 0.0017
# Epoch [3/6], Batch [280], Loss: 0.0885
# Epoch [3/6], Batch [290], Loss: 0.0881
# Epoch [3/6], Batch [300], Loss: 0.0889
# Epoch [3/6], Batch [310], Loss: 0.1739
# Epoch [3/6], Batch [320], Loss: 0.0446
# Epoch [3/6], Batch [330], Loss: 0.1309
# Epoch [3/6], Batch [340], Loss: 0.0875
# Epoch [3/6], Batch [350], Loss: 0.2180
# Epoch [3/6], Batch [360], Loss: 0.0451
# Epoch [3/6], Batch [370], Loss: 0.1312
# Epoch [3/6], Batch [380], Loss: 0.0295
# Epoch [3/6], Batch [390], Loss: 0.0898
# Epoch [3/6], Batch [400], Loss: 0.1311
# Epoch [3/6], Batch [410], Loss: 0.2178
# Epoch [3/6], Batch [420], Loss: 0.0216
# Epoch [3/6], Batch [430], Loss: 0.0446
# Epoch [3/6], Batch [440], Loss: 0.1321
# Epoch [3/6], Batch [450], Loss: 0.1740
# Epoch [3/6], Batch [460], Loss: 0.5658
# Epoch [3/6], Batch [470], Loss: 0.0019
# Epoch [3/6], Batch [480], Loss: 0.2612
# Epoch [3/6], Batch [490], Loss: 0.3747
# Epoch [3/6], Batch [500], Loss: 0.0097
# Epoch 3/6, Loss: 0.0952, Accuracy: 0.8768
# Validation Loss: 0.0115, Validation Accuracy: 0.9956
# Epoch [4/6], Batch [0], Loss: 0.0191
# Epoch [4/6], Batch [10], Loss: 0.0402
# Epoch [4/6], Batch [20], Loss: 0.0875
# Epoch [4/6], Batch [30], Loss: 0.1747
# Epoch [4/6], Batch [40], Loss: 0.0022
# Epoch [4/6], Batch [50], Loss: 0.1744
# Epoch [4/6], Batch [60], Loss: 0.0020
# Epoch [4/6], Batch [70], Loss: 0.1745
# Epoch [4/6], Batch [80], Loss: 0.0881
# Epoch [4/6], Batch [90], Loss: 0.0445
# Epoch [4/6], Batch [100], Loss: 0.2179
# Epoch [4/6], Batch [110], Loss: 0.1756
# Epoch [4/6], Batch [120], Loss: 0.2686
# Epoch [4/6], Batch [130], Loss: 0.0466
# Epoch [4/6], Batch [140], Loss: 0.0446
# Epoch [4/6], Batch [150], Loss: 0.0120
# Epoch [4/6], Batch [160], Loss: 0.1351
# Epoch [4/6], Batch [170], Loss: 0.0442
# Epoch [4/6], Batch [180], Loss: 0.0881
# Epoch [4/6], Batch [190], Loss: 0.0886
# Epoch [4/6], Batch [200], Loss: 0.0444
# Epoch [4/6], Batch [210], Loss: 0.3417
# Epoch [4/6], Batch [220], Loss: 0.0304
# Epoch [4/6], Batch [230], Loss: 0.0449
# Epoch [4/6], Batch [240], Loss: 0.0097
# Epoch [4/6], Batch [250], Loss: 0.1755
# Epoch [4/6], Batch [260], Loss: 0.0300
# Epoch [4/6], Batch [270], Loss: 0.0384
# Epoch [4/6], Batch [280], Loss: 0.0874
# Epoch [4/6], Batch [290], Loss: 0.1739
# Epoch [4/6], Batch [300], Loss: 0.0888
# Epoch [4/6], Batch [310], Loss: 0.1314
# Epoch [4/6], Batch [320], Loss: 0.1315
# Epoch [4/6], Batch [330], Loss: 0.1755
# Epoch [4/6], Batch [340], Loss: 0.0373
# Epoch [4/6], Batch [350], Loss: 0.0455
# Epoch [4/6], Batch [360], Loss: 0.0459
# Epoch [4/6], Batch [370], Loss: 0.0886
# Epoch [4/6], Batch [380], Loss: 0.1319
# Epoch [4/6], Batch [390], Loss: 0.0448
# Epoch [4/6], Batch [400], Loss: 0.1315
# Epoch [4/6], Batch [410], Loss: 0.0291
# Epoch [4/6], Batch [420], Loss: 0.0444
# Epoch [4/6], Batch [430], Loss: 0.0323
# Epoch [4/6], Batch [440], Loss: 0.0448
# Epoch [4/6], Batch [450], Loss: 0.0029
# Epoch [4/6], Batch [460], Loss: 0.0885
# Epoch [4/6], Batch [470], Loss: 0.1747
# Epoch [4/6], Batch [480], Loss: 0.0467
# Epoch [4/6], Batch [490], Loss: 0.0885
# Epoch [4/6], Batch [500], Loss: 0.0885
# Epoch 4/6, Loss: 0.0992, Accuracy: 0.8736
# Validation Loss: 0.0114, Validation Accuracy: 0.9956
# Epoch [5/6], Batch [0], Loss: 0.0010
# Epoch [5/6], Batch [10], Loss: 0.1793
# Epoch [5/6], Batch [20], Loss: 0.0326
# Epoch [5/6], Batch [30], Loss: 0.0874
# Epoch [5/6], Batch [40], Loss: 0.0019
# Epoch [5/6], Batch [50], Loss: 0.0458
# Epoch [5/6], Batch [60], Loss: 0.0097
# Epoch [5/6], Batch [70], Loss: 0.0186
# Epoch [5/6], Batch [80], Loss: 0.1746
# Epoch [5/6], Batch [90], Loss: 0.0021
# Epoch [5/6], Batch [100], Loss: 0.0878
# Epoch [5/6], Batch [110], Loss: 0.0454
# Epoch [5/6], Batch [120], Loss: 0.0024
# Epoch [5/6], Batch [130], Loss: 0.0014
# Epoch [5/6], Batch [140], Loss: 0.1318
# Epoch [5/6], Batch [150], Loss: 0.0876
# Epoch [5/6], Batch [160], Loss: 0.0448
# Epoch [5/6], Batch [170], Loss: 0.0879
# Epoch [5/6], Batch [180], Loss: 0.0191
# Epoch [5/6], Batch [190], Loss: 0.0455
# Epoch [5/6], Batch [200], Loss: 0.0882
# Epoch [5/6], Batch [210], Loss: 0.0453
# Epoch [5/6], Batch [220], Loss: 0.0014
# Epoch [5/6], Batch [230], Loss: 0.0887
# Epoch [5/6], Batch [240], Loss: 0.0886
# Epoch [5/6], Batch [250], Loss: 0.1305
# Epoch [5/6], Batch [260], Loss: 0.0447
# Epoch [5/6], Batch [270], Loss: 0.0467
# Epoch [5/6], Batch [280], Loss: 0.0428
# Epoch [5/6], Batch [290], Loss: 0.1739
# Epoch [5/6], Batch [300], Loss: 0.0450
# Epoch [5/6], Batch [310], Loss: 0.1315
# Epoch [5/6], Batch [320], Loss: 0.1314
# Epoch [5/6], Batch [330], Loss: 0.0446
# Epoch [5/6], Batch [340], Loss: 0.0883
# Epoch [5/6], Batch [350], Loss: 0.1316
# Epoch [5/6], Batch [360], Loss: 0.0877
# Epoch [5/6], Batch [370], Loss: 0.0887
# Epoch [5/6], Batch [380], Loss: 0.0888
# Epoch [5/6], Batch [390], Loss: 0.1745
# Epoch [5/6], Batch [400], Loss: 0.5749
# Epoch [5/6], Batch [410], Loss: 0.3163
# Epoch [5/6], Batch [420], Loss: 0.0449
# Epoch [5/6], Batch [430], Loss: 0.0215
# Epoch [5/6], Batch [440], Loss: 0.5750
# Epoch [5/6], Batch [450], Loss: 0.0189
# Epoch [5/6], Batch [460], Loss: 0.0005
# Epoch [5/6], Batch [470], Loss: 0.0473
# Epoch [5/6], Batch [480], Loss: 0.0461
# Epoch [5/6], Batch [490], Loss: 0.0275
# Epoch [5/6], Batch [500], Loss: 0.4700
# Epoch 5/6, Loss: 0.0952, Accuracy: 0.8771
# Validation Loss: 0.0114, Validation Accuracy: 0.9956
# Epoch [6/6], Batch [0], Loss: 0.0018
# Epoch [6/6], Batch [10], Loss: 0.0879
# Epoch [6/6], Batch [20], Loss: 0.1314
# Epoch [6/6], Batch [30], Loss: 0.0886
# Epoch [6/6], Batch [40], Loss: 0.1744
# Epoch [6/6], Batch [50], Loss: 0.0448
# Epoch [6/6], Batch [60], Loss: 0.0545
# Epoch [6/6], Batch [70], Loss: 0.0021
# Epoch [6/6], Batch [80], Loss: 0.1318
# Epoch [6/6], Batch [90], Loss: 0.1315
# Epoch [6/6], Batch [100], Loss: 0.0018
# Epoch [6/6], Batch [110], Loss: 0.0878
# Epoch [6/6], Batch [120], Loss: 0.0457
# Epoch [6/6], Batch [130], Loss: 0.5751
# Epoch [6/6], Batch [140], Loss: 0.0883
# Epoch [6/6], Batch [150], Loss: 0.0011
# Epoch [6/6], Batch [160], Loss: 0.0003
# Epoch [6/6], Batch [170], Loss: 0.0882
# Epoch [6/6], Batch [180], Loss: 0.0017
# Epoch [6/6], Batch [190], Loss: 0.0451
# Epoch [6/6], Batch [200], Loss: 0.1746
# Epoch [6/6], Batch [210], Loss: 0.0025
# Epoch [6/6], Batch [220], Loss: 0.0455
# Epoch [6/6], Batch [230], Loss: 0.0396
# Epoch [6/6], Batch [240], Loss: 0.0450
# Epoch [6/6], Batch [250], Loss: 0.0874
# Epoch [6/6], Batch [260], Loss: 0.2486
# Epoch [6/6], Batch [270], Loss: 0.0014
# Epoch [6/6], Batch [280], Loss: 0.1310
# Epoch [6/6], Batch [290], Loss: 0.0192
# Epoch [6/6], Batch [300], Loss: 0.0876
# Epoch [6/6], Batch [310], Loss: 0.0462
# Epoch [6/6], Batch [320], Loss: 0.0884
# Epoch [6/6], Batch [330], Loss: 0.6174
# Epoch [6/6], Batch [340], Loss: 0.5659
# Epoch [6/6], Batch [350], Loss: 0.5751
# Epoch [6/6], Batch [360], Loss: 0.0445
# Epoch [6/6], Batch [370], Loss: 0.0442
# Epoch [6/6], Batch [380], Loss: 0.0188
# Epoch [6/6], Batch [390], Loss: 0.0342
# Epoch [6/6], Batch [400], Loss: 0.0882
# Epoch [6/6], Batch [410], Loss: 0.0269
# Epoch [6/6], Batch [420], Loss: 0.1309
# Epoch [6/6], Batch [430], Loss: 0.1314
# Epoch [6/6], Batch [440], Loss: 0.0366
# Epoch [6/6], Batch [450], Loss: 0.0878
# Epoch [6/6], Batch [460], Loss: 0.0451
# Epoch [6/6], Batch [470], Loss: 0.0888
# Epoch [6/6], Batch [480], Loss: 0.0021
# Epoch [6/6], Batch [490], Loss: 0.1308
# Epoch [6/6], Batch [500], Loss: 0.1309
# Epoch 6/6, Loss: 0.0961, Accuracy: 0.8872
# Validation Loss: 0.0114, Validation Accuracy: 0.9956
# Model saved to E:/python-projects/llm/Trained_models/codebert_classifier0.8872217439429344.pth
